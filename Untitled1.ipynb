# %% [markdown]
# <a href="https://colab.research.google.com/github/Mani111zo/zozo1/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
up= files.upload()
b = list(up.keys())[0]
# Out:
#      <input type="file" id="files-50b06cdf-c9dd-465b-a111-01a4b81d0e93" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50b06cdf-c9dd-465b-a111-01a4b81d0e93">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv(b)
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.head(95)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 90     91  5ef6d3eefdD43bE       Nina    Chavez
# 91     92  98b3aeDcC3B9FF3      Shane     Foley
# 92     93  aAb6AFc7AfD0fF3     Collin     Ayers
# 93     94  54B5B5Fe9F1B6C5     Sherry     Young
# 94     95  BE91A0bdcA49Bbc    Darrell   Douglas
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.tail(98)
# Out:
#     Index      Customer Id First Name Last Name  \
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# 5       6  2d08FB17EE273F4      Aimee     Downs
# 6       7  EA4d384DfDbBf77     Darren      Peck
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company             City  \
# 2                     Murillo-Perry    Isabelborough
# 3   Dominguez, Mcmillan and Donovan       Bensonview
# 4          Martin, Lang and Andrade   West Priscilla
# 5                      Steele Group    Chavezborough
# 6      Lester, Woodard and Mitchell         Lake Ana
# ..                              ...              ...
# ...

# %%
df.head(98)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 93     94  54B5B5Fe9F1B6C5     Sherry     Young
# 94     95  BE91A0bdcA49Bbc    Darrell   Douglas
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.tail(80)
# Out:
#     Index      Customer Id First Name   Last Name                     Company  \
# 20     21  9F9AdB7B8A6f7F2    Maxwell        Frye               Patterson Inc
# 21     22  FBd0Ded4F02a742      Kiara     Houston  Manning, Hester and Arroyo
# 22     23  2FB0FAA1d429421    Colleen      Howard              Greer and Sons
# 23     24  010468dAA11382c      Janet  Valenzuela             Watts-Donaldson
# 24     25  eC1927Ca84E033e      Shane      Wilcox                  Tucker LLC
# ..    ...              ...        ...         ...                         ...
# 95     96  cb8E23e48d22Eae       Karl       Greer                   Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn    Atkinson       Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred      Guerra               Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne      Farmer          Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence      Haynes          Le, Nash and Cross
#
# ...

# %%
df.head(95)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 90     91  5ef6d3eefdD43bE       Nina    Chavez
# 91     92  98b3aeDcC3B9FF3      Shane     Foley
# 92     93  aAb6AFc7AfD0fF3     Collin     Ayers
# 93     94  54B5B5Fe9F1B6C5     Sherry     Young
# 94     95  BE91A0bdcA49Bbc    Darrell   Douglas
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
#importing the module

import pandas as pd

#creating a sample dataframe

data = pd.DataFrame({'Brand': ['Maruti', 'Hyundai', 'Tata',

'Mahindra', 'Maruti', 'Hyundai', 'Renault', 'Tata', 'Maruti'],

'Year': [2012, 2014, 2011, 2015, 2012, 2016, 2014, 2018, 2019],

'Kms Driven': [50000, 30000, 60000,
25000, 10000, 46000, 31000, 15000, 12000],

'City': ['Gurgaon', 'Delhi', 'Mumbai',

'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Chennai', 'Ghaziabad'],

'Mileage': [28, 27, 25, 26, 28,

29, 24, 21, 24]})

# displaying the DataFrame

display(data)
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1   Hyundai  2014       30000      Delhi       27
# 2      Tata  2011       60000     Mumbai       25
# 3  Mahindra  2015       25000      Delhi       26
# 4    Maruti  2012       10000     Mumbai       28
# 5   Hyundai  2016       46000      Delhi       29
# 6   Renault  2014       31000     Mumbai       24
# 7      Tata  2018       15000    Chennai       21
# 8    Maruti  2019       12000  Ghaziabad       24

# %%
df1 ={'Name':["varun","shuui","acddb","DDD","shirosagi","valt","darara"],"Id": [1,2,3,4,5,6,7]}
df=pd.DataFrame(df1)
df
# Out:
#         Name  Id
# 0      varun   1
# 1      shuui   2
# 2      acddb   3
# 3        DDD   4
# 4  shirosagi   5
# 5       valt   6
# 6     darara   7

# %%
df2 ={'Name':["varun","freedelahoya","shuui","acddb","obito","shirosagi","doffy"],"Id": [1,2,3,4,5,6,7]}
df=pd.DataFrame(df2)
df
# Out:
#            Name  Id
# 0         varun   1
# 1  freedelahoya   2
# 2         shuui   3
# 3         acddb   4
# 4         obito   5
# 5     shirosagi   6
# 6         doffy   7

# %% [markdown]
# dict1 ={'Name':["varun","shuui","acddb","DDD","shirosagi"],"Id": [1,2,3,4,5]}
# df=pd.DataFrame(dict1)
# df
